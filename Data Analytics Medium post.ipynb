# %% [markdown]
# #### Introduction (Giriş) to (-a) Data (Məlumat) Analytics (Analitikası)
#
# - **It is the process of transforming raw data into valuable information that supports decision-making based on scientific, mathematical, and statistical principles.**
# - **It is the process of converting raw data into valuable information to support decision-making using scientific, mathematical, and statistical foundations.**
#
# **Data (Məlumat) analytics (analitikası) is (-dır) the (-) process (prosesidir) of (-ın) inspecting (yoxlanılması), transforming (çevrilməsi), and (və) modeling (modelləşdirilməsi) data (məlumatların) to (-maq üçün) discover (aşkar etmək) useful (faydalı) insights (anlayışlar / nəticələr) and (və) support (dəstəkləmək) decision-making (qərar qəbuletməni) in (-də) various (müxtəlif) fields (sahələrdə).**
#
# **It (Bu) involves (əhatə edir) the (-) use (istifadəsini) of (-ın) advanced (inkişaf etmiş) analytic (analitik) tools (alətlər), reports (hesabatlar), and (və) visualizations (vizuallaşdırmalar) to (-maq üçün) make (etmək) sense (məna) of (-nı) complex (mürəkkəb) datasets (məlumat dəstlərinin) and (və) drive (istiqamətləndirmək) informed (məlumatlı) decisions (qərarları) for (üçün) business (biznes) growth (artımı).**
#
# **In (-də) this (bu) introductory (giriş xarakterli) post (yazıda), we (biz) will (-acağıq) explore (araşdıracağıq) the (-) world (dünyasını) of (-nın) data (məlumat) analytics (analitikasının), its (onun) importance (əhəmiyyətini), and (və) some (bəzi) popular (məşhur) tools (alətləri) and (və) techniques (texnikaları) used (istifadə olunan) in (-də) the (-) field (sahədə).**

# %% [markdown]
# - **to discover** useful  **insights** - faydalı **anlayışlar** / nəticələr **aşkar etmək**
# - insights - anlayışlar
# - **to support** **decision-making** - **qərar qəbuletməni** **dəstəkləmək**
# - in **various** fields  - **müxtəlif** sahələrdə
# - It **involves** - bu **əhatə edir**
# - to make sense — məntiqli olmaq / başa düşülən olmaq
# - **to drive** informed decisions — məlumatlı qərarlar verməyə **istiqamətləndirmək**
# - for business **growth** — biznesin **artımı** üçün
# - In this **introductory** post — Bu **giriş xarakterli** yazıda
# - we will **explore** — biz **araşdıracağıq**
# - some - bəzi
# - its **importance** — onun **əhəmiyyəti**
# - techniques used in the field — sahədə istifadə olunan texnikaları

# %% [markdown]
# #### Importance (Əhəmiyyəti) of (-ın) Data (Məlumat) Analytics (Analitikasının)
#
# **Data (Məlumat) analytics (analitikası) plays (oynayır / oynayır) a (-) crucial (vacib) role (rol) in (-də) today’s (bugünkü) data-driven (məlumat yönümlü) world (dünyada), as (çünki) it (o) helps (kömək edir) organizations (təşkilatlara) make (etmək) informed (məlumatlı) decisions (qərarlar) based (əsasında) on (-ın) the (-) insights (nəticələr / anlayışlar) derived (çıxarılan) from (-dan) their (onların) data (məlumat). Some (Bəzi) key (əsas) benefits (faydaları) of (-ın) data (məlumat) analytics (analitikasının) include (daxildir):**
#
# - **1. Improved (Təkmilləşdirilmiş) decision-making (qərar qəbuletmə): Data (Məlumat) analytics (analitikası) enables (imkan verir) organizations (təşkilatlara) to (etmək üçün) make (qərarlar) data-driven (məlumat yönümlü) decisions (qərarlar), reducing (azaldaraq) the (-) reliance (asılılığı) on (-a) intuition (intuisiyaya / daxili hissə) and (və) guesswork (tahminlər / təxminlər).**
#
# - **2. Increased (Artan) efficiency (səmərəlilik): By (vasitəsilə) identifying (müəyyən edərək) patterns (nümunələri) and (və) trends (trendləri) in (-də) data (məlumat), organizations (təşkilatlar) can (bacarır) optimize (optimallaşdırmaq) their (öz) processes (prosesləri) and (və) improve (təkmilləşdirmək) overall (ümumi) efficiency (səmərəliliyi).**
#
# - **3. Competitive (Rəqabət) advantage (üstünlük): Data (Məlumat) analytics (analitikası) can (bacarır) provide (təmin etmək) valuable (dəyərli) insights (nəticələr) that (ki) give (verir) an (bir) organization (təşkilata) a (-) competitive (rəqabətli) edge (üstünlük) in (-də) the (-) market (bazar).**

# %% [markdown]
# - crucial - həlledici / mühüm
# - **data-driven** world — **məlumat yönümlü** dünya
# - as - çünki
# - to make informed decisions — məlumatlı qərarlar vermək
# - based on the insights **derived** from their data — onların məlumatından **çıxarılan** nəticələr əsasında
# - some key **benefits** — Bəzi əsas **faydaları**
# - **improved** decision-making — **təkmilləşdirilmiş** qərar qəbuletmə
# - **to improve - təkmilləşdirmək**
# - Data analytics **enables** — Məlumat analitikası **imkan verir**
# - **to reduce** — **azaltmaq**
# - reducing **the reliance** on intuition — intuisiyaya **asılılığı** azaldaraq
# - reliance - etibar
# - addiction - asılılıq
# - guesswork - təxminlər / təxmin
# - approximately - təxminən
# - increased **efficiency** — artan **səmərəlilik**
# - **By identifying** patterns and trends in data — Məlumatda nümunələri və trendləri **müəyyən edərək**
# - to improve **overall** efficiency — **ümumi** səmərəliliyi təkmilləşdirmək
# - **competitive advantage** — **rəqabət üstünlüyü**
# - **competitive - rəqabətli**
# - **competition - rəqabət**
# - **advantage** / **preference** - **üstünlük**
# - to gained an advantage — üstünlük qazandı
# - to gained the upper hand - üstünlük qazandı / üstünlük əldə etdi / üstün gəldi
# - valuable - dəyərli
# - to provide - təmin etmək
# - to offer - təklif etmək
# - edge - kənar
# - competitive **edge** in the market — bazar üzrə rəqabətli **üstünlük**

# %% [markdown]
# #### Popular (Məşhur) Data (Məlumat) Analytics (Analitikası) Tools (Alətləri)
#
# **There (Var) are (dir) several (bir neçə) tools (alətlər) and (və) software (proqram təminatı) available (mövcuddur) for (- üçün) data (məlumat) analytics (analitikası), each (hər biri) with (ilə) its (öz) unique (unikal / xüsusi) features (xüsusiyyətlər) and (və) capabilities (bacarıqlar / imkanlar). Some (Bəzi) popular (məşhur) tools (alətlər) include (daxildir):**
#
# - **1.Power (Power) BI (BI): A (-) versatile (çoxistiqamətli / çoxfunksiyalı) and (və) platform-independent (platformadan asılı olmayan) tool (alət) that (ki) offers (təklif edir) advanced (inkişaf etmiş) analytic (analitik) tools (alətlər), reports (hesabatlar), and (və) visualizations (vizuallaşdırmalar).**
#
# - **2.Tableau (Tableau) Public (Public): A (-) free (pulsuz) data (məlumat) visualization (vizuallaşdırma) software (proqram təminatı) that (ki) provides (təklif edir) daily (gündəlik) datasets (məlumat dəstlərini) for (- üçün) analysis (analiz) and (və) allows (icazə verir) users (istifadəçilərə) to (etmək üçün) accurately (dəqiq) plot (çizim etmək), chart (qrafik yaratmaq), and (və) map (xəritələşdirmək) data (məlumat).**
#
# - **3.Python (Python): A (-) programming (proqramlaşdırma) language (dili) widely (geniş) used (istifadə olunan) for (- üçün) data (məlumat) analysis (analiz) and (və) visualization (vizuallaşdırma), with (ilə) libraries (kitabxanalar) such as (kimi) Pandas (Pandas) and (və) Matplotlib (Matplotlib) for (- üçün) data (məlumat) manipulation (əməliyyat / manipulyasiya) and (və) visualization (vizuallaşdırma).**
